# %%
import pandas as pd
import numpy as np

# %%
my_file = pd.read_csv('sales_records.csv')
my_file
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia              NaN
# 3                  Sub-Saharan Africa  Sao Tome and Principe              NaN
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali              NaN
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
print(my_file[0:5]['Total Profit'])
# Out:
# 0    951410.50
# 1    248406.36
# 2    224598.75
# 3     19525.82
# 4    639077.50
# Name: Total Profit, dtype: float64

# %%
print(my_file['Item Type'].isnull().value_counts())
# Out:
# False    94
# True      6
# Name: Item Type, dtype: int64

# %%
my_file = my_file.fillna('Unknown')
my_file
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia          Unknown
# 3                  Sub-Saharan Africa  Sao Tome and Principe          Unknown
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Unknown
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...
